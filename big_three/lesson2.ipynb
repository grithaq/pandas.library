# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_lenght  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
logic = df['class'] == 'Iris-setosa'
df[logic].head()
# Out:
#    sepal_length  sepal_width  petal_lenght  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
logic2 = df['sepal_length'] > 7
df_high = df[logic2]
df_high
# Out:
#      sepal_length  sepal_width  petal_lenght  petal_width           class
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 125           7.2          3.2           6.0          1.8  Iris-virginica
# 129           7.2          3.0           5.8          1.6  Iris-virginica
# 130           7.4          2.8           6.1          1.9  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica

# %%
# df_high.to_csv('data/sepal_morethan7.0.csv', index=False)

# %%
# df_high.to_excel('data/sepal_forexcel.xls', index=False)

# %%
df_high.plot()

# %%
df['class'].describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: class, dtype: object

# %%
df['class_codes']=pd.Categorical(df['class']).codes
df.head()
# Out:
#    sepal_length  sepal_width  petal_lenght  petal_width        class  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    class_codes
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_lenght  petal_width  \
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_lenght      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000
# class_codes       0.782561    -0.419446      0.949043     0.956464
#
#               class_codes
# sepal_length     0.782561
# sepal_width     -0.419446
# petal_lenght     0.949043
# petal_width      0.956464
# class_codes      1.000000
